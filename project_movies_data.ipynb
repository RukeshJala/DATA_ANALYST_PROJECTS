# %% [markdown]
# <a href="https://colab.research.google.com/github/RukeshJala/DATA_ANALYST_PROJECTS/blob/main/project_movies_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/movies_metadata.csv", engine="python", on_bad_lines='skip')

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 26604  False                                                NaN         0
# 26605  False                                                NaN         0
# 26606  False                                                NaN         0
# 26607  False                                                NaN         0
# 26608  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.shape
# Out:
# (26609, 24)

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# #Adult

# %%
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    23540
# budget                       0
# genres                       0
# homepage                 22211
# id                           0
# imdb_id                     12
# original_language            3
# original_title               0
# overview                   258
# popularity                   2
# poster_path                143
# production_companies         1
# production_countries         1
# release_date                29
# revenue                      2
# runtime                     59
# spoken_languages             2
# status                      36
# tagline                  12038
# title                        2
# video                        2
# vote_average                 2
# vote_count                   2
# dtype: int64

# %%
df=df.dropna(subset="adult")
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    23540
# budget                       0
# genres                       0
# homepage                 22211
# id                           0
# imdb_id                     12
# original_language            3
# original_title               0
# overview                   258
# popularity                   2
# poster_path                143
# production_companies         1
# production_countries         1
# release_date                29
# revenue                      2
# runtime                     59
# spoken_languages             2
# status                      36
# tagline                  12038
# title                        2
# video                        2
# vote_average                 2
# vote_count                   2
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#        adult belongs_to_collection budget  \
# 1465   False                   NaN      0
# 9165   False                   NaN      0
# 9327   False                   NaN      0
# 13375  False                   NaN      0
# 16764  False                   NaN      0
# 21165  False                   NaN      0
# 21854  False                   NaN      0
# 22151  False                   NaN      0
# 23044  False                   NaN      0
# 24844  False                   NaN      0
#
#                                                   genres  \
# 1465   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 9165   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 9327   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 13375  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 16764  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 21165  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 21854  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# ...

# %%
df=df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df["adult"]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26604    False
# 26605    False
# 26606    False
# 26607    False
# 26608    False
# Name: adult, Length: 26599, dtype: object

# %%
df["adult"].value_counts()
# Out:
# adult
# False                  26597
# True                       1
#  - Written by Ørnås        1
# Name: count, dtype: int64

# %%
# df=df.loc[df["adult"].isin(["True","False"])]

# %%
# df["adult"]=df["adult"].map({"True":True,"False":False})

# %%
df["adult"].dtype
# Out:
# dtype('O')

# %% [markdown]
# #Belongs_to_collection

# %%
df.belongs_to_collection.values[1]
# Out:
# nan

# %%
df.belongs_to_collection.values[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %% [markdown]
# if the values is not nan then convert string->dictionary and get name value else if value is na,append0 to my ids

# %%
import ast
ast.literal_eval(df.belongs_to_collection.values[0])['name']
# Out:
# 'Toy Story Collection'

# %%
import ast
import numpy as np

kousik = []
for i in df['belongs_to_collection'].values:
  if i == i:

    kousik.append(ast.literal_eval(i)['name'])
  else:

    kousik.append("no collecetion")

df['collectionName'] = kousik
df = df.drop(columns = ['belongs_to_collection'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2989232867.py in <cell line: 0>()
#       6   if i == i:
#       7
# ----> 8     kousik.append(ast.literal_eval(i)['name'])
#       9   else:
#      10
#
# TypeError: 'float' object is not subscriptable

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 26604  False                                                NaN         0
# 26605  False                                                NaN         0
# 26606  False                                                NaN         0
# 26607  False                                                NaN         0
# 26608  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    23530
# budget                       0
# genres                       0
# homepage                 22203
# id                           0
# imdb_id                     12
# original_language            3
# original_title               0
# overview                   258
# popularity                   2
# poster_path                143
# production_companies         1
# production_countries         1
# release_date                29
# revenue                      2
# runtime                     59
# spoken_languages             2
# status                      36
# tagline                  12032
# title                        2
# video                        2
# vote_average                 2
# vote_count                   2
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 26604  False                                                NaN         0
# 26605  False                                                NaN         0
# 26606  False                                                NaN         0
# 26607  False                                                NaN         0
# 26608  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#df["belongs_to_collection"].value_counts()

# %% [markdown]
# #Budget

# %%
df["budget"][0]
# Out:
# '30000000'

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 26604  False                                                NaN         0
# 26605  False                                                NaN         0
# 26606  False                                                NaN         0
# 26607  False                                                NaN         0
# 26608  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.budget = df.budget.astype('int64')
df.budget.describe()

# %%
sum(df.budget == 0)

# %%
sum(df.budget == 0)*100/df.shape[0]

# %%
df

# %%
df.isna().sum()

# %%
df["budget"]

# %% [markdown]
# #Genres

# %%
df.genres

# %%
df.genres.unique()

# %%
ast.literal_eval(df.genres.values[0])

# %%
uniqueGenres = set()

# %%
uniqueGenres

# %%
len(uniqueGenres)

# %%
moviegenres = ["action","adventure"]
uniqueGenres = ["action","adventure","family","horror"]

row = []
for j in uniqueGenres:
  row.append(int(j in moviegenres))

  row

# %%
# Assuming uniqueGenres from the previous cell is the list of genres you want as columns
genres = uniqueGenres
genre = pd.DataFrame([row], columns = genres)
genre

# %%
genre.shape

# %%
df

# %%
# df = pd.concat([df,genre], axis = 1) # Joining the two Dataframes
# df.shape, genre.shape

# %%
# df = df.drop(columns = ['genres'])

# %%
# df

# %% [markdown]
# #Homepage

# %%
df.homepage

# %%
~df.homepage.isnull()

# %%
df.homepage.isnull().sum()*100/df.shape[0]

# %%
df['homepagepresent'] = (~df.homepage.isnull())

# %%
df = df.drop(columns = ['homepage'])
